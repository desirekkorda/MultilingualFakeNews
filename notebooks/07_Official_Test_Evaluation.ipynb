# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# verify project exists
import os

print(os.path.exists(
    "/content/drive/MyDrive/MultilingualFakeNews"
))
# Out:
# True

# %%
# Add project root
import sys

PROJECT_ROOT = "/content/drive/MyDrive/MultilingualFakeNews"

if PROJECT_ROOT not in sys.path:
    sys.path.append(PROJECT_ROOT)

print("Project root added.")
# Out:
# Project root added.

# %%
# verify Python code can see src
import os

print(os.listdir(
    "/content/drive/MyDrive/MultilingualFakeNews"
))
# Out:
# ['data', 'models', 'src', 'notebooks']

# %%
from src.dataset import FakeNewsDataset
from src.model import XLMRClassifier
from src.config import *
from src.train import train_epoch
from src.evaluate import eval_epoch

# %%
# Paths

PROJECT_ROOT = "/content/drive/MyDrive/MultilingualFakeNews"

DATA_DIR = f"{PROJECT_ROOT}/data"

MODEL_DIR = f"{PROJECT_ROOT}/models"

# %% [markdown]
# Importing Successful. Actual Code for Notebook 7 begins. Henceforth, every notebook will have the following header:
#
# # ==========================================
# # PROJECT BOOTSTRAP
# # ==========================================
#
# from google.colab import drive
# drive.mount('/content/drive')
#
# import sys
#
# PROJECT_ROOT = "/content/drive/MyDrive/MultilingualFakeNews"
#
# if PROJECT_ROOT not in sys.path:
#     sys.path.append(PROJECT_ROOT)
#
# print("Project ready.")

# %%
import pandas as pd
import torch

from torch.utils.data import DataLoader
from transformers import AutoTokenizer

from src.dataset import FakeNewsDataset
from src.model import XLMRClassifier
from src.config import *
from src.train import train_epoch
from src.evaluate import eval_epoch

# %%
import os

TEST_DIR = "/content/TALLIP/TALLIP-FakeNews-Dataset/English/Test"

print(os.path.exists(TEST_DIR))

if os.path.exists(TEST_DIR):
    print(os.listdir(TEST_DIR))
# Out:
# False

# %%
import os

print(os.listdir("/content/drive/MyDrive"))
# Out:
# ['plantvillage-dataset.zip', 'plant-disease-recognition-ai-challenger.zip', 'Colab Notebooks', 'plantvillage dataset', 'PlantDoc_Classification', 'AI_Challenger_Plant', 'MultilingualFakeNews']

# %%
import os

DATA_DIR = "/content/drive/MyDrive/MultilingualFakeNews/data"

print(os.path.exists(DATA_DIR))

if os.path.exists(DATA_DIR):
    print(os.listdir(DATA_DIR))
# Out:
# True
# ['TALLIP-FakeNews-Dataset.zip', 'english_clean.csv', 'english_clean_v2.csv']

# %%
import os

print(os.listdir("/content/drive/MyDrive/MultilingualFakeNews/data"))
# Out:
# ['TALLIP-FakeNews-Dataset.zip', 'english_clean.csv', 'english_clean_v2.csv']

# %%
import zipfile
import os

zip_path = "/content/drive/MyDrive/MultilingualFakeNews/data/TALLIP-FakeNews-Dataset.zip"

extract_path = "/content/drive/MyDrive/MultilingualFakeNews/data/TALLIP-FakeNews-Dataset"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("Dataset extracted.")
# Out:
# Dataset extracted.

# %%
import os

dataset_root = "/content/drive/MyDrive/MultilingualFakeNews/data/TALLIP-FakeNews-Dataset"

print(os.listdir(dataset_root))
# Out:
# ['English', 'Hindi', 'Indonesian', 'Multilingual', 'Readme.txt', 'Swahili', 'Vietnamese']

# %%
import os

for root, dirs, files in os.walk(
    "/content/drive/MyDrive/MultilingualFakeNews/data/TALLIP-FakeNews-Dataset"
):
    for file in files:
        if "English" in file or "english" in file:
            print(os.path.join(root, file))
# Out:
# /content/drive/MyDrive/MultilingualFakeNews/data/TALLIP-FakeNews-Dataset/English/Test/test_English_Data_Business.txt
# /content/drive/MyDrive/MultilingualFakeNews/data/TALLIP-FakeNews-Dataset/English/Test/test_English_Data_Celebrity_Full.txt
# /content/drive/MyDrive/MultilingualFakeNews/data/TALLIP-FakeNews-Dataset/English/Test/test_English_Data_Complete_FakeNews.txt
# /content/drive/MyDrive/MultilingualFakeNews/data/TALLIP-FakeNews-Dataset/English/Test/test_English_Data_Education.txt
# /content/drive/MyDrive/MultilingualFakeNews/data/TALLIP-FakeNews-Dataset/English/Test/test_English_Data_Entertainment.txt
# /content/drive/MyDrive/MultilingualFakeNews/data/TALLIP-FakeNews-Dataset/English/Test/test_English_Data_Politics.txt
# /content/drive/MyDrive/MultilingualFakeNews/data/TALLIP-FakeNews-Dataset/English/Test/test_English_Data_Sports.txt
# /content/drive/MyDrive/MultilingualFakeNews/data/TALLIP-FakeNews-Dataset/English/Test/test_English_Data_Technology.txt
# ...

# %%
DATASET_ROOT = f"{DATA_DIR}/TALLIP-FakeNews-Dataset"

ENGLISH_TRAIN_PATH = ...
ENGLISH_TEST_PATH = ...

# %%
print(os.listdir(dataset_root))
# Out:
# ['English', 'Hindi', 'Indonesian', 'Multilingual', 'Readme.txt', 'Swahili', 'Vietnamese']

# %%
import os

english_root = "/content/drive/MyDrive/MultilingualFakeNews/data/TALLIP-FakeNews-Dataset/English"

for root, dirs, files in os.walk(english_root):
    print("\nFolder:", root)

    for file in files:
        print("   ", file)
# Out:
# Folder: /content/drive/MyDrive/MultilingualFakeNews/data/TALLIP-FakeNews-Dataset/English
#
# Folder: /content/drive/MyDrive/MultilingualFakeNews/data/TALLIP-FakeNews-Dataset/English/Test
#     test_English_Data_Business.txt
#     test_English_Data_Celebrity_Full.txt
#     test_English_Data_Complete_FakeNews.txt
#     test_English_Data_Education.txt
#     test_English_Data_Entertainment.txt
#     test_English_Data_Politics.txt
#     test_English_Data_Sports.txt
#     test_English_Data_Technology.txt
#
# Folder: /content/drive/MyDrive/MultilingualFakeNews/data/TALLIP-FakeNews-Dataset/English/Train
#     train_English_Data_Business.txt
#     train_English_Data_Celebrity_Full.txt
#     train_English_Data_Complete_FakeNews.txt
#     train_English_Data_Education.txt
#     train_English_Data_Entertainment.txt
#     train_English_Data_Politics.txt
#     train_English_Data_Sports.txt
#     train_English_Data_Technology.txt

# %%
# Dataset Paths

DATASET_ROOT = f"{DATA_DIR}/TALLIP-FakeNews-Dataset"

ENGLISH_DIR = f"{DATASET_ROOT}/English"

ENGLISH_TRAIN_PATH = "..."
ENGLISH_TEST_PATH = "..."

# %%
print(test_df.shape)

print(test_df.columns)

print(test_df["Label"].value_counts())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2222/2025400490.py in <cell line: 0>()
# ----> 1 print(test_df.shape)
#       2
#       3 print(test_df.columns)
#       4
#       5 print(test_df["Label"].value_counts())
#
# NameError: name 'test_df' is not defined
