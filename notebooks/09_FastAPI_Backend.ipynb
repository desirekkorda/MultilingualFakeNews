# %%
from google.colab import drive
drive.mount('/content/drive')

import sys

PROJECT_ROOT = "/content/drive/MyDrive/MultilingualFakeNews"

if PROJECT_ROOT not in sys.path:
    sys.path.append(PROJECT_ROOT)

print("Project ready.")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_4397/3644002778.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#       3
#       4 import sys
#       5
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     270             'https://research.google.com/colaboratory/faq.html#drive-timeout'
#     271         )
# ...

# %%
# !pip install fastapi uvicorn nest-asyncio pyngrok

# %%
import fastapi
import uvicorn
import nest_asyncio
import pyngrok

print("FastAPI installation successful!")
# Out:
# FastAPI installation successful!

# %%
import os

os.makedirs("/content/drive/MyDrive/MultilingualFakeNews/app/api", exist_ok=True)

files = [
    "__init__.py",
    "main.py",
    "routes.py",
    "schemas.py"
]

for file in files:
    path = f"/content/drive/MyDrive/MultilingualFakeNews/app/api/{file}"
    if not os.path.exists(path):
        open(path, "w").close()

print("API structure created.")
# Out:
# API structure created.

# %%
# !pip install nest_asyncio pyngrok

# %%
import nest_asyncio

nest_asyncio.apply()

print("Async patch applied.")
# Out:
# Async patch applied.

# %%
# Add project root
import sys

PROJECT_ROOT = "/content/drive/MyDrive/MultilingualFakeNews"

if PROJECT_ROOT not in sys.path:
    sys.path.append(PROJECT_ROOT)

print("Project root added.")
# Out:
# Project root added.

# %%
# !cat /content/drive/MyDrive/MultilingualFakeNews/app/api/main.py
# Out:
# from fastapi import FastAPI
#
# from app.api.routes import router
#
# app = FastAPI(
#     title="Multilingual Fake News Detection API",
#     version="1.1.0",
#     description="REST API for fake news detection using XLM-RoBERTa"
# )
#
# app.include_router(router)

# %%
import sys

PROJECT_PATH = "/content/drive/MyDrive/MultilingualFakeNews"

if PROJECT_PATH not in sys.path:
    sys.path.append(PROJECT_PATH)

from app.api.main import app

print("API imported successfully.")
# Out:
# API imported successfully.

# %%
import nest_asyncio

nest_asyncio.apply()

print("Async patch applied.")

# %%
from google.colab import userdata
from pyngrok import ngrok

# Safely fetch the token from Colab's secrets
try:
    NGROK_AUTH_TOKEN = userdata.get('NGROK_TOKEN')
    ngrok.set_auth_token(NGROK_AUTH_TOKEN)

    public_url = ngrok.connect(8000)
    print("Public URL:", public_url)
except Exception as e:
    print("Make sure you've added your NGROK_TOKEN to the Colab Secrets tab!")
# Out:
# Public URL: NgrokTunnel: "https://cinema-cinema-grandkid.ngrok-free.dev" -> "http://localhost:8000"

# %%
# !pip install pytest

# %%
# !pytest -v tests/test_api.py
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.13, pytest-8.4.2, pluggy-1.6.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /content
# plugins: anyio-4.14.0, typeguard-4.5.2, langsmith-0.9.1
# collected 0 items
#
# ============================ no tests ran in 0.00s =============================
# ERROR: file or directory not found: tests/test_api.py

# %%
import sys

PROJECT_PATH = "/content/drive/MyDrive/MultilingualFakeNews"

if PROJECT_PATH not in sys.path:
    sys.path.append(PROJECT_PATH)

# %%
# !pytest -v tests/test_api.py
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.13, pytest-8.4.2, pluggy-1.6.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /content
# plugins: anyio-4.14.0, typeguard-4.5.2, langsmith-0.9.1
# collected 0 items
#
# ============================ no tests ran in 0.00s =============================
# ERROR: file or directory not found: tests/test_api.py

# %%
import pytest

pytest.main(["/content/drive/MyDrive/MultilingualFakeNews/tests/test_api.py", "-v"])
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.13, pytest-8.4.2, pluggy-1.6.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /content
# plugins: anyio-4.14.0, typeguard-4.5.2, langsmith-0.9.1
# collecting ... collected 4 items
#
# drive/MyDrive/MultilingualFakeNews/tests/test_api.py::test_root PASSED   [ 25%]
# drive/MyDrive/MultilingualFakeNews/tests/test_api.py::test_health PASSED [ 50%]
# drive/MyDrive/MultilingualFakeNews/tests/test_api.py::test_predict
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/615 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.10M [00:00<?, ?B/s]
# ...
